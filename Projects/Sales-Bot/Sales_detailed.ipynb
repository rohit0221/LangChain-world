# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel
from langchain_openai import ChatOpenAI
import pandas as pd

model = ChatOpenAI(model="gpt-4o-mini",temperature=0)

# %%
from data_models import *
from MonthlySales_Data import *
from RegionalSales_Data import *
# Out:
# c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\hub.py:86: DeprecationWarning: The `langchainhub sdk` is deprecated.
# Please use the `langsmith sdk` instead:
#   pip install langsmith
# Use the `pull_prompt` method.
#   res_dict = client.pull_repo(owner_repo_commit)

# %%
MonthlySales_Data=MonthlySalesData_chain.invoke({"query": MonthlySalesData_query})
MonthlySales_Data=RegionalSalesData_chain.invoke({"query": RegionalSalesData_query})

# %%
MonthlySales_Data
# Out:
# [{'month': 'January 2020',
#   'sales_volume_units': 50000,
#   'revenue_million_usd': 150,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'February 2020',
#   'sales_volume_units': 45000,
#   'revenue_million_usd': 135,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'March 2020',
#   'sales_volume_units': 60000,
#   'revenue_million_usd': 180,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'April 2020',
#   'sales_volume_units': 55000,
#   'revenue_million_usd': 165,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'May 2020',
#   'sales_volume_units': 70000,
#   'revenue_million_usd': 210,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'June 2020',
#   'sales_volume_units': 80000,
#   'revenue_million_usd': 240,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'July 2020',
#   'sales_volume_units': 75000,
#   'revenue_million_usd': 225,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'August 2020',
#   'sales_volume_units': 90000,
# ...

# %%
MonthlySales_Data
# Out:
# [{'month': 'January 2020',
#   'sales_volume_units': 50000,
#   'revenue_million_usd': 150,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'February 2020',
#   'sales_volume_units': 45000,
#   'revenue_million_usd': 135,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'March 2020',
#   'sales_volume_units': 60000,
#   'revenue_million_usd': 180,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'April 2020',
#   'sales_volume_units': 55000,
#   'revenue_million_usd': 165,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'May 2020',
#   'sales_volume_units': 70000,
#   'revenue_million_usd': 210,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'June 2020',
#   'sales_volume_units': 80000,
#   'revenue_million_usd': 240,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'July 2020',
#   'sales_volume_units': 75000,
#   'revenue_million_usd': 225,
#   'average_price_per_unit_usd': 3.0},
#  {'month': 'August 2020',
#   'sales_volume_units': 90000,
# ...

# %%
MonthlySales_df = pd.DataFrame(MonthlySales_Data)
RegionalSales_df = pd.DataFrame(MonthlySales_Data)

# %%
MonthlySales_df
# Out:
#              month  sales_volume_units  revenue_million_usd  \
# 0     January 2020               50000                  150
# 1    February 2020               45000                  135
# 2       March 2020               60000                  180
# 3       April 2020               55000                  165
# 4         May 2020               70000                  210
# 5        June 2020               80000                  240
# 6        July 2020               75000                  225
# 7      August 2020               90000                  270
# 8   September 2020               85000                  255
# 9     October 2020               95000                  285
# 10   November 2020              100000                  300
# 11   December 2020              120000                  360
# 12    January 2021              110000                  330
# 13   February 2021              105000                  315
# 14      March 2021              115000                  345
# ...

# %%
RegionalSales_df
# Out:
#              month  sales_volume_units  revenue_million_usd  \
# 0     January 2020               50000                  150
# 1    February 2020               45000                  135
# 2       March 2020               60000                  180
# 3       April 2020               55000                  165
# 4         May 2020               70000                  210
# 5        June 2020               80000                  240
# 6        July 2020               75000                  225
# 7      August 2020               90000                  270
# 8   September 2020               85000                  255
# 9     October 2020               95000                  285
# 10   November 2020              100000                  300
# 11   December 2020              120000                  360
# 12    January 2021              110000                  330
# 13   February 2021              105000                  315
# 14      March 2021              115000                  345
# ...

# %%
def fetch_data_by_year(df, year):
    """
    Fetches data for a specific year from the DataFrame called "MonthlySales_df"
    
    Args:
    df (pd.DataFrame): The DataFrame containing the sales data.
    year (int): The year for which data is required.
    
    Returns:
    pd.DataFrame: Filtered DataFrame containing data for the specified year.
    """
    return df[df['month'].str.contains(str(year))].reset_index(drop=True)

# %%
fetch_data_by_year(MonthlySales_df,2021)
# Out:
#              month  sales_volume_units  revenue_million_usd  \
# 0     January 2021              110000                  330
# 1    February 2021              105000                  315
# 2       March 2021              115000                  345
# 3       April 2021              120000                  360
# 4         May 2021              130000                  390
# 5        June 2021              140000                  420
# 6        July 2021              135000                  405
# 7      August 2021              145000                  435
# 8   September 2021              150000                  450
# 9     October 2021              160000                  480
# 10   November 2021              170000                  510
# 11   December 2021              180000                  540
#
#     average_price_per_unit_usd  Year      Month
# 0                          3.0  2021 2021-01-01
# 1                          3.0  2021 2021-02-01
# ...

# %%
import pandas as pd

def summarize_sales_data(df: pd.DataFrame) -> pd.DataFrame:
    """
    Provides a summary of the sales data, including total, mean, median, and standard deviation.
    
    Args:
    df (pd.DataFrame): The DataFrame containing the sales data.
    
    Returns:
    pd.DataFrame: A DataFrame summarizing total, mean, median, and standard deviation.
    """
    summary = {
        'Total Sales Volume': df['sales_volume_units'].sum(),
        'Mean Sales Volume': df['sales_volume_units'].mean(),
        'Median Sales Volume': df['sales_volume_units'].median(),
        'Std Dev Sales Volume': df['sales_volume_units'].std(),
        'Total Revenue': df['revenue_million_usd'].sum(),
        'Mean Revenue': df['revenue_million_usd'].mean(),
        'Median Revenue': df['revenue_million_usd'].median(),
        'Std Dev Revenue': df['revenue_million_usd'].std(),
        'Total Average Price': df['average_price_per_unit_usd'].mean()  # Assuming uniform price across months
    }
    return pd.DataFrame([summary])

# %%
from testfunc import *


### 4. **Example Usage**


# Summarize Sales Data
summary_df = summarize_sales_data(MonthlySales_df)
print(summary_df)
# Out:
#    Total Sales Volume  Mean Sales Volume  Median Sales Volume  \
# 0             4960000      137777.777778             137500.0
#
#    Std Dev Sales Volume  Total Revenue  Mean Revenue  Median Revenue  \
# 0          55038.226254          14880    413.333333           412.5
#
#    Std Dev Revenue  Total Average Price
# 0       165.114679                  3.0

# %%
# Yearly Sales Summary
yearly_summary_df = yearly_sales_summary(MonthlySales_df)
print(yearly_summary_df)
# Out:
#    Year  Total_Sales_Volume  Total_Revenue
# 0  2020              925000           2775
# 1  2021             1660000           4980
# 2  2022             2375000           7125

# %%
# Monthly Sales Trend
monthly_trend_df = monthly_sales_trend(MonthlySales_df)
print(monthly_trend_df)
# Out:
#             sales_volume_units  revenue_million_usd
# Month
# 2020-01-01               50000                  150
# 2020-02-01               45000                  135
# 2020-03-01               60000                  180
# 2020-04-01               55000                  165
# 2020-05-01               70000                  210
# 2020-06-01               80000                  240
# 2020-07-01               75000                  225
# 2020-08-01               90000                  270
# 2020-09-01               85000                  255
# 2020-10-01               95000                  285
# 2020-11-01              100000                  300
# 2020-12-01              120000                  360
# 2021-01-01              110000                  330
# 2021-02-01              105000                  315
# 2021-03-01              115000                  345
# 2021-04-01              120000                  360
# 2021-05-01              130000                  390
# ...

# %%
# Plot Monthly Trends
plot_monthly_trends(MonthlySales_df)

# %%
# Plot Yearly Sales Summary
plot_yearly_sales_summary(yearly_summary_df)

# %%
# Plot Heatmap
plot_heatmap(MonthlySales_df)

# %%
from MonthlySales_Data import *
MonthlySales_agent_executor.invoke({
    "input": "Provide a summary of yearly statistics."
})
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `yearly_summary` with `{'df': 'MonthlySales_df'}`
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 from MonthlySales_Data import *
# ----> 2 MonthlySales_agent_executor.invoke({
#       3     "input": "Provide a summary of yearly statistics{MonthlySales_df}."
#       4 })
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
# ...

# %%
from MonthlySales_Data import *
MonthlySales_agent_executor.invoke({
    "input": "Give me the sales data for the year 2021."
})
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `fetch_data_by_year` with `{'df': 'MonthlySales_df', 'year': 2021}`
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 from MonthlySales_Data import *
# ----> 2 MonthlySales_agent_executor.invoke({
#       3     "input": "Give me the sales data for the year 2021."
#       4 })
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
# ...
