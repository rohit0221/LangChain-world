# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel
from langchain_openai import ChatOpenAI
import pandas as pd

model = ChatOpenAI(model="gpt-4o-mini",temperature=0)

# %%
from data_models import *
from MonthlySales_Data import *
from RegionalSales_Data import *

# %%
MonthlySales_Data=MonthlySalesData_chain.invoke({"query": MonthlySalesData_query})
RegionalSales_Data=RegionalSalesData_chain.invoke({"query": RegionalSalesData_query})

# %%
MonthlySales_df = pd.DataFrame(MonthlySales_Data)
RegionalSales_df = pd.DataFrame(MonthlySales_Data)

# %%
MonthlySales_df
# Out:
#              month  sales_volume_units  revenue_million_usd  \
# 0     January 2020               50000                  150
# 1    February 2020               45000                  135
# 2       March 2020               60000                  180
# 3       April 2020               55000                  165
# 4         May 2020               70000                  210
# 5        June 2020               80000                  240
# 6        July 2020               75000                  225
# 7      August 2020               90000                  270
# 8   September 2020               85000                  255
# 9     October 2020               95000                  285
# 10   November 2020              100000                  300
# 11   December 2020              120000                  360
# 12    January 2021              110000                  330
# 13   February 2021              105000                  315
# 14      March 2021              115000                  345
# ...

# %%
RegionalSales_df
# Out:
#              month  sales_volume_units  revenue_million_usd  \
# 0     January 2020               50000                  150
# 1    February 2020               45000                  135
# 2       March 2020               60000                  180
# 3       April 2020               55000                  165
# 4         May 2020               70000                  210
# 5        June 2020               80000                  240
# 6        July 2020               75000                  225
# 7      August 2020               90000                  270
# 8   September 2020               85000                  255
# 9     October 2020               95000                  285
# 10   November 2020              100000                  300
# 11   December 2020              120000                  360
# 12    January 2021              110000                  330
# 13   February 2021              105000                  315
# 14      March 2021              115000                  345
# ...

# %%
# from MonthlySales_Data import *

# MonthlySales_tools = [
#     fetch_data_by_year,
#     fetch_data_by_month_year,
#     fetch_data_by_date_range,
#     plot_sales_revenue,
#     plot_monthly_revenue,
#     plot_avg_price_per_unit,
#     plot_heatmap_sales_revenue,
#     plot_correlation_heatmap,
#     monthly_summary,
#     yearly_summary
# ]

# llm = ChatOpenAI(model="gpt-4o-mini")

# llm_with_tools = llm.bind_tools(MonthlySales_tools)

# from langchain import hub

# # Get the prompt to use - you can modify this!
# prompt = hub.pull("hwchase17/openai-functions-agent")
# prompt.messages

# from langchain.agents import create_tool_calling_agent

# MonthlySales_agent = create_tool_calling_agent(llm, MonthlySales_tools, prompt)

# from langchain.agents import AgentExecutor

# MonthlySales_agent_executor = AgentExecutor(agent=MonthlySales_agent, tools=MonthlySales_tools, verbose=True)

# %%
from MonthlySales_Data import *
MonthlySales_agent_executor.invoke({
    "input": "Give me the sales data for the year 2021."
})
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `fetch_data_by_year` with `{'df': None, 'year': 2021}`
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 from MonthlySales_Data import *
# ----> 2 MonthlySales_agent_executor.invoke({
#       3     "input": "Give me the sales data for the year 2021."
#       4 })
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
# ...

# %%
response = MonthlySales_agent_executor.invoke({
    "input": "Give me the sales data for the year 2021.",
    "df": MonthlySales_df,  # Pass the DataFrame here
    "year": 2021            # Pass the year here
})
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `fetch_data_by_year` with `{'df': 'sales_data', 'year': 2021}`
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 response = MonthlySales_agent_executor.invoke({
#       2     "input": "Give me the sales data for the year 2021.",
#       3     "df": MonthlySales_df,  # Pass the DataFrame here
#       4     "year": 2021            # Pass the year here
#       5 })
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# ...

# %%
def fetch_data_by_year(df, year):
    """
    Fetches data for a specific year from the DataFrame called "MonthlySales_df"
    
    Args:
    df (pd.DataFrame): The DataFrame containing the sales data.
    year (int): The year for which data is required.
    
    Returns:
    pd.DataFrame: Filtered DataFrame containing data for the specified year.
    """
    return df[df['month'].str.contains(str(year))].reset_index(drop=True)

# %%
fetch_data_by_year(MonthlySales_df,2021)
# Out:
#              month  sales_volume_units  revenue_million_usd  \
# 0     January 2021              110000                  330
# 1    February 2021              105000                  315
# 2       March 2021              115000                  345
# 3       April 2021              120000                  360
# 4         May 2021              130000                  390
# 5        June 2021              140000                  420
# 6        July 2021              135000                  405
# 7      August 2021              145000                  435
# 8   September 2021              150000                  450
# 9     October 2021              160000                  480
# 10   November 2021              170000                  510
# 11   December 2021              180000                  540
#
#     average_price_per_unit_usd
# 0                          3.0
# 1                          3.0
# 2                          3.0
# 3                          3.0
# ...

# %%
plot_sales_revenue(MonthlySales_df)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plot_sales_revenue(MonthlySales_df)
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\langchain_core\tools.py:567, in BaseTool.__call__(self, tool_input, callbacks)
#     564 @deprecated("0.1.47", alternative="invoke", removal="0.3.0")
#     565 def __call__(self, tool_input: str, callbacks: Callbacks = None) -> str:
#     566     """Make tool callable."""
# --> 567     return self.run(tool_input, callbacks=callbacks)
#
# ...
