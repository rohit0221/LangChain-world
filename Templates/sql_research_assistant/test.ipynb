# %%
from langchain_community.utilities import SQLDatabase
from pathlib import Path


db_path = "nba_roster.db"
# rel = db_path.relative_to(Path.cwd())
db_string = f"sqlite:///{db_path}"
db = SQLDatabase.from_uri(db_string, sample_rows_in_table_info=2)

# %%
db.get_table_info()
# Out:
# '\nCREATE TABLE nba_roster (\n\t"Team" TEXT, \n\t"NAME" TEXT, \n\t"Jersey" TEXT, \n\t"POS" TEXT, \n\t"AGE" INTEGER, \n\t"HT" TEXT, \n\t"WT" TEXT, \n\t"COLLEGE" TEXT, \n\t"SALARY" TEXT\n)\n\n/*\n2 rows from nba_roster table:\nTeam\tNAME\tJersey\tPOS\tAGE\tHT\tWT\tCOLLEGE\tSALARY\nAtlanta Hawks\tSaddiq Bey\t41\tSF\t24\t6\' 7"\t215 lbs\tVillanova\t$4,556,983\nAtlanta Hawks\tBogdan Bogdanovic\t13\tSG\t31\t6\' 5"\t225 lbs\t--\t$18,700,000\n*/'

# %%
from langchain_community.utilities import SQLDatabase

print(db.dialect)
print(db.get_usable_table_names())
# Out:
# sqlite
# ['nba_roster']

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain.chains import create_sql_query_chain

chain = create_sql_query_chain(llm, db)
response = chain.invoke({"question": "How many employees are there."})
response
# Out:
# 'SQLQuery: SELECT COUNT(*) AS "EmployeeCount" FROM nba_roster;'

# %%
db.run("SELECT COUNT(*) AS 'employee_count' FROM nba_roster;")
# Out:
# '[(600,)]'

# %%
from sql_answer import sql_chain

# %%
response = sql_chain.invoke({"question": "How many employees are there."})

# %%
response
# Out:
# '```sql\nSELECT COUNT(*) AS total_employees FROM employees;\n```'

# %%
db.run("SELECT COUNT(*) AS total_employees FROM employees;")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Code\Github\LangChain-Basics\venv\lib\site-packages\sqlalchemy\engine\default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# OperationalError: no such table: employees
#
# The above exception was the direct cause of the following exception:
#
# ...
